# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Data Preview

# %%
main_df = pd.read_csv('input/Iowa_Liquor_Sales.csv')
# Out:
# /Users/zekieordoveza/Desktop/Z/Liquor-Sales-EDA/lsp-env/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
main_df.head()
# Out:
#   Invoice/Item Number        Date  Store Number  \
# 0        S29198800001  11/20/2015          2191
# 1        S29195400002  11/21/2015          2205
# 2        S29050300001  11/16/2015          3549
# 3        S28867700001  11/04/2015          2513
# 4        S29050800001  11/17/2015          3942
#
#                          Store Name              Address          City  \
# 0                    Keokuk Spirits            1013 MAIN        KEOKUK
# 1            Ding's Honk And Holler     900 E WASHINGTON      CLARINDA
# 2              Quicker Liquor Store         1414 48TH ST  FORT MADISON
# 3  Hy-Vee Food Store #2 / Iowa City       812  S 1ST AVE     IOWA CITY
# 4                  Twin Town Liquor  104 HIGHWAY 30 WEST        TOLEDO
#
#   Zip Code                                     Store Location  County Number  \
# 0    52632    1013 MAIN\nKEOKUK 52632\n(40.39978, -91.387531)           56.0
# 1    51632  900 E WASHINGTON\nCLARINDA 51632\n(40.739238, ...           73.0
# ...

# %%
lsdf = main_df

lsdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12591077 entries, 0 to 12591076
# Data columns (total 24 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Invoice/Item Number    object
#  1   Date                   object
#  2   Store Number           int64
#  3   Store Name             object
#  4   Address                object
#  5   City                   object
#  6   Zip Code               object
#  7   Store Location         object
#  8   County Number          float64
#  9   County                 object
#  10  Category               float64
#  11  Category Name          object
#  12  Vendor Number          float64
#  13  Vendor Name            object
#  14  Item Number            int64
#  15  Item Description       object
#  16  Pack                   int64
#  17  Bottle Volume (ml)     int64
#  18  State Bottle Cost      object
#  19  State Bottle Retail    object
#  20  Bottles Sold           int64
# ...

# %%
lsdf.describe()
# Out:
#        Store Number  County Number      Category  Vendor Number   Item Number  \
# count  1.259108e+07   1.251190e+07  1.258306e+07   1.259107e+07  1.259108e+07
# mean   3.565216e+03   5.724050e+01  1.044710e+06   2.574911e+02  4.603682e+04
# std    9.312721e+02   2.726983e+01  5.435094e+04   1.416175e+02  5.301684e+04
# min    2.106000e+03   1.000000e+00  1.012200e+05   1.000000e+01  1.010000e+02
# 25%    2.604000e+03   3.100000e+01  1.012210e+06   1.150000e+02  2.705600e+04
# 50%    3.704000e+03   6.200000e+01  1.031200e+06   2.600000e+02  3.817700e+04
# 75%    4.304000e+03   7.700000e+01  1.062310e+06   3.800000e+02  6.375500e+04
# max    9.932000e+03   9.900000e+01  1.901200e+06   9.870000e+02  9.992750e+05
#
#                Pack  Bottle Volume (ml)  Bottles Sold  Volume Sold (Liters)  \
# count  1.259108e+07        1.259108e+07  1.259108e+07          1.259108e+07
# mean   1.222533e+01        9.289402e+02  8.140392e+00          7.489119e+00
# ...

# %%
# lsdf["Sale (Dollars)"].value_counts()
lsdf.hist(bins=50, figsize=(20,15))
# Out:
# array([[<AxesSubplot:title={'center':'Store Number'}>,
#         <AxesSubplot:title={'center':'County Number'}>,
#         <AxesSubplot:title={'center':'Category'}>],
#        [<AxesSubplot:title={'center':'Vendor Number'}>,
#         <AxesSubplot:title={'center':'Item Number'}>,
#         <AxesSubplot:title={'center':'Pack'}>],
#        [<AxesSubplot:title={'center':'Bottle Volume (ml)'}>,
#         <AxesSubplot:title={'center':'Bottles Sold'}>,
#         <AxesSubplot:title={'center':'Volume Sold (Liters)'}>],
#        [<AxesSubplot:title={'center':'Volume Sold (Gallons)'}>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
lsdf.dtypes
# Out:
# Invoice/Item Number       object
# Date                      object
# Store Number               int64
# Store Name                object
# Address                   object
# City                      object
# Zip Code                  object
# Store Location            object
# County Number            float64
# County                    object
# Category                 float64
# Category Name             object
# Vendor Number            float64
# Vendor Name               object
# Item Number                int64
# Item Description          object
# Pack                       int64
# Bottle Volume (ml)         int64
# State Bottle Cost         object
# State Bottle Retail       object
# Bottles Sold               int64
# Sale (Dollars)            object
# Volume Sold (Liters)     float64
# Volume Sold (Gallons)    float64
# dtype: object

# %%
lsdf.columns
# Out:
# Index(['Invoice/Item Number', 'Date', 'Store Number', 'Store Name', 'Address',
#        'City', 'Zip Code', 'Store Location', 'County Number', 'County',
#        'Category', 'Category Name', 'Vendor Number', 'Vendor Name',
#        'Item Number', 'Item Description', 'Pack', 'Bottle Volume (ml)',
#        'State Bottle Cost', 'State Bottle Retail', 'Bottles Sold',
#        'Sale (Dollars)', 'Volume Sold (Liters)', 'Volume Sold (Gallons)'],
#       dtype='object')

# %%
lsdf['Bottles Sold'].hist(range=[1, 20])
# Out:
# <AxesSubplot:>

# %%
lsdf['Category Name'].head(15)
# Out:
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# 5                                NaN
# 6     DECANTERS & SPECIALTY PACKAGES
# 7                                NaN
# 8     DECANTERS & SPECIALTY PACKAGES
# 9                                NaN
# 10                               NaN
# 11                               NaN
# 12                               NaN
# 13    DECANTERS & SPECIALTY PACKAGES
# 14                               NaN
# Name: Category Name, dtype: object

# %% [markdown]
# # Cleaning

# %% [markdown]
# **NULL VALUES**

# %%
# get numeric columns
lsdf_num = lsdf.select_dtypes(include=[np.number])

lsdf_num
# Out:
#           Store Number  County Number   Category  Vendor Number  Item Number  \
# 0                 2191           56.0        NaN          255.0          297
# 1                 2205           73.0        NaN          255.0          297
# 2                 3549           56.0        NaN          130.0          249
# 3                 2513           52.0        NaN           65.0          237
# 4                 3942           86.0        NaN          130.0          249
# ...                ...            ...        ...            ...          ...
# 12591072          5423           71.0  1071100.0          305.0        73802
# 12591073          5423           71.0  1011200.0           85.0        20375
# 12591074          5423           71.0  1011500.0           85.0        20372
# 12591075          5423           71.0  1011200.0           85.0        20369
# 12591076          5423           71.0  1091100.0          481.0        77309
#
# ...

# %%
type(lsdf_num.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
for col in lsdf_num.columns:
    print(col + ": ", lsdf_num[col].isnull().values.any())
# Out:
# Store Number:  False
# County Number:  True
# Category:  True
# Vendor Number:  True
# Item Number:  False
# Pack:  False
# Bottle Volume (ml):  False
# Bottles Sold:  False
# Volume Sold (Liters):  False
# Volume Sold (Gallons):  False

# %% [markdown]
# **DATA TYPE CONVERSIONS**

# %% [markdown]
# Object -> Dates:

# %%
lsdf['Date'] = pd.to_datetime(lsdf['Date'])

# %%
lsdf.Date.head(15)
# Out:
# 0    2015-11-20
# 1    2015-11-21
# 2    2015-11-16
# 3    2015-11-04
# 4    2015-11-17
# 5    2015-11-11
# 6    2015-11-09
# 7    2015-11-10
# 8    2015-11-30
# 9    2015-11-16
# 10   2015-11-17
# 11   2015-11-05
# 12   2015-11-09
# 13   2015-11-11
# 14   2015-11-19
# Name: Date, dtype: datetime64[ns]

# %% [markdown]
# Currency -> Numeric:

# %%
lsdf.head()
# Out:
#   Invoice/Item Number       Date  Store Number  \
# 0        S29198800001 2015-11-20          2191
# 1        S29195400002 2015-11-21          2205
# 2        S29050300001 2015-11-16          3549
# 3        S28867700001 2015-11-04          2513
# 4        S29050800001 2015-11-17          3942
#
#                          Store Name              Address          City  \
# 0                    Keokuk Spirits            1013 MAIN        KEOKUK
# 1            Ding's Honk And Holler     900 E WASHINGTON      CLARINDA
# 2              Quicker Liquor Store         1414 48TH ST  FORT MADISON
# 3  Hy-Vee Food Store #2 / Iowa City       812  S 1ST AVE     IOWA CITY
# 4                  Twin Town Liquor  104 HIGHWAY 30 WEST        TOLEDO
#
#   Zip Code                                     Store Location  County Number  \
# 0    52632    1013 MAIN\nKEOKUK 52632\n(40.39978, -91.387531)           56.0
# 1    51632  900 E WASHINGTON\nCLARINDA 51632\n(40.739238, ...           73.0
# ...

# %%
#Sale (Dollars)
lsdf['Sale (Dollars)'] = main_df['Sale (Dollars)'].astype(str)
lsdf['Sale (Dollars)'] = lsdf['Sale (Dollars)'].map(lambda x: x.replace('$',''))
lsdf['Sale (Dollars)'] = lsdf['Sale (Dollars)'].astype(str).astype(float)

# %%
#State Bottle Retail
lsdf['State Bottle Retail'] = main_df['State Bottle Retail'].astype(str)
lsdf['State Bottle Retail'] = lsdf['State Bottle Retail'].map(lambda x: x.replace('$',''))
lsdf['State Bottle Retail'] = lsdf['State Bottle Retail'].astype(str).astype(float)

# %%
#State Bottle Cost
lsdf['State Bottle Cost'] = main_df['State Bottle Cost'].astype(str)
lsdf['State Bottle Cost'] = lsdf['State Bottle Cost'].map(lambda x: x.replace('$',''))
lsdf['State Bottle Cost'] = lsdf['State Bottle Cost'].astype(str).astype(float)

# %%
lsdf.head()
# Out:
#   Invoice/Item Number       Date  Store Number  \
# 0        S29198800001 2015-11-20          2191
# 1        S29195400002 2015-11-21          2205
# 2        S29050300001 2015-11-16          3549
# 3        S28867700001 2015-11-04          2513
# 4        S29050800001 2015-11-17          3942
#
#                          Store Name              Address          City  \
# 0                    Keokuk Spirits            1013 MAIN        KEOKUK
# 1            Ding's Honk And Holler     900 E WASHINGTON      CLARINDA
# 2              Quicker Liquor Store         1414 48TH ST  FORT MADISON
# 3  Hy-Vee Food Store #2 / Iowa City       812  S 1ST AVE     IOWA CITY
# 4                  Twin Town Liquor  104 HIGHWAY 30 WEST        TOLEDO
#
#   Zip Code                                     Store Location  County Number  \
# 0    52632    1013 MAIN\nKEOKUK 52632\n(40.39978, -91.387531)           56.0
# 1    51632  900 E WASHINGTON\nCLARINDA 51632\n(40.739238, ...           73.0
# ...

# %% [markdown]
# Object -> String

# %%
# Store Name  
lsdf['Store Name'] = lsdf['Store Name'].astype(str)                     
# Address     
lsdf['Address'] = lsdf['Address'].astype(str)                     
# City    
lsdf['City'] = lsdf['City'].astype(str) 
# Store Location 
lsdf['Store Location'] = lsdf['Store Location'].astype(str)                     
# County   
lsdf['County'] = lsdf['County'].astype(str)   
# Category Name   
lsdf['Category Name'] = lsdf['Category Name'].astype(str)
# Vendor Name  
lsdf['Vendor Name'] = lsdf['Vendor Name'].astype(str)     
# Item Description    
lsdf['Item Description'] = lsdf['Item Description'].astype(str)

# %% [markdown]
# Object -> Integer

# %%
lsdf['Zip Code'].head(10)
# Out:
# 0    52632
# 1    51632
# 2    52627
# 3    52240
# 4    52342
# 5    51025
# 6    50702
# 7    52342
# 8    52761
# 9    712-2
# Name: Zip Code, dtype: object

# %%
# Zip Code                         
# lsdf['Zip Code'] = lsdf['Zip Code'].astype(int)

# %%
# Cleaned df
lsdf.to_csv('output/Iowa_Liquor_Sales_Cleaned.csv')
